# %%
# The input would be the name of the item from the dataset that the user likes the most.
# The output would be the dataset that is sorted based on the similarity score generated from the selected item.

# %%
import pandas as pd
import nltk
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
pd.set_option('display.max_rows', None)
df1 = pd.read_csv('timhortons.csv', encoding= 'unicode_escape')
df2 = pd.read_csv('subway.csv', encoding= 'unicode_escape')
df3 = df1.append(df2, ignore_index=True)
df4 = pd.read_csv('mcdonalds.csv', encoding= 'unicode_escape')
df =  df3.append(df4, ignore_index=True)
#conversion of all the text data into upper case to make our life easier.
df = df.apply(lambda x: x.astype(str).str.upper())
#keyword addition from name of the column
item_name_column = df['Menu Item']
def get_key_words_from_column(name_column):
    keywords = []
    for i in name_column:
        keywords.append(tokenizer.tokenize(i))
    return keywords
Keywords_col = pd.Series(get_key_words_from_column(item_name_column))
df['Keywords'] = Keywords_col
# extracting keywords from columns and appending it to the keyword column
columns = df.columns.to_list()
for col in columns:
    if((columns.index(col)>2) & (columns.index(col)!= columns.index("Keywords")) & (columns.index(col)!= columns.index("Keywords"))):
        #print(col)
        for i, r in df.iterrows():
            if (r[col] == 'X' or r[col] == 'O'):
                if col.upper() not in r['Keywords']:
                    r['Keywords'].append(col.upper())
                    #print(f"{i} : {r['Keywords']}")
        #         else:
        #             #print('present')
        #             print(f"{i} : {r['Keywords']}")
        #     else:
        #         #print('present')
        #         print(f"{i} : {r['Keywords']}")
#df[["Menu Item",'Keywords']]
#df.head(5)
for i, r in df.iterrows():
    if r["Item Temp"] not in r['Keywords']:
        r['Keywords'].append(r["Item Temp"])
        
#df[["Menu Item",'Keywords']]
df_keywords = df[['Menu Item','Keywords']]
Keyword_dict = df_keywords.set_index('Menu Item').to_dict()['Keywords']
#importing the main dataset and adding a column index for better referencing
dataframe = pd.read_csv('FoodChain_1.2.csv')
def add_index_column(df):
    index = []
    for i, r in df.iterrows():
        index.append(i)
    return index
index_col = pd.Series(add_index_column(dataframe))
#print(index_col)
dataframe['Index'] = index_col
#converting all the values into upper case
#match and fill the dictonary values and fill them in the main dataset.
#if no match found use the name to generate keywords and fill.
dataframe = dataframe.apply(lambda x: x.astype(str).str.upper())
df3 = dataframe#[dataframe['Food chain'] == 'TIM HORTONS']
df3 = df3.assign(Keywords='NAN')
for i, r in df3.iterrows():
    if (Keyword_dict.get(r['Menu Items'])):
        r['Keywords']=Keyword_dict.get(r['Menu Items'])
    else:
        r['Keywords']=tokenizer.tokenize(r['Menu Items'])
#index_col
Keyword_data = df3

# cosine similarity application for the Tims data.

import numpy as np
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
#Load the preprocessed data.
# Converting the data column data of keywords into a string, appending the string, drop the keyword column
Keyword_data['Keywords_str'] = [' '.join(map(str, l)) for l in Keyword_data['Keywords']]
Keyword_data.drop(['Keywords'], axis=1)
#Done with the keyword addition in string format
# Defining the features
features = ['Food chain', "Menu Category", "Keywords_str"]
#Replacing the missing null values in all the four columns
for f in features:
    #print(type(f))
    Keyword_data[f] = Keyword_data[f].fillna(".")
# concatinating all the features from the dataset items into a single string.
total_features = Keyword_data['Food chain']+" "+ Keyword_data["Menu Category"]+ " "+Keyword_data["Keywords_str"]
# TF-IDF 
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(total_features)
#Cosine_similarity score
similarity = cosine_similarity(feature_vectors)
#Get the item name from the user
item = input("enter the item name: ")
list_of_items = Keyword_data["Menu Items"].tolist()
item_close_match = difflib.get_close_matches(item, list_of_items)
index_of_the_item = Keyword_data[Keyword_data["Menu Items"] == item_close_match[0]]['Index'].values[0]
#getting the list of similar movies
Keyword_data[Keyword_data['Index'] == index_of_the_item].index
similarity_score = list(enumerate(similarity[int(index_of_the_item)]))
#print(similarity_score)
#plotting of the similarity scores
import matplotlib.pyplot as plt
# %matplotlib inline
x=[]
y=[]
for i in similarity_score:
    x.append(i[0])
    y.append(i[1])
y
# # Graph 1
# data_for_plot = Keyword_data
# fig, axes = plt.subplots(nrows=1,ncols=1)
# axes.bar(x,y,color='green')
# #axes.bar(x,y=1,marker="*")
# # Graph 2
# data_for_plot['Similarity_Score']= y
# data_for_plot
# import plotly.express as px
# #data_canada = px.data.gapminder().query("country == 'Canada'")
# type(similarity_score)
# fig = px.bar(data_for_plot, x='Index', y='Similarity_Score',hover_name="Menu Items",hover_data=["Food chain","Energy (kCal)"],title="Similarity_scores")
# fig.show()
# Sorting the dataset
sorted_items_based_on_liking = sorted(similarity_score, key = lambda x:x[1], reverse = True) 

title = []
for i in sorted_items_based_on_liking:
    index = i[0]
    #print(index)
    title.append(Keyword_data[Keyword_data['Index'] == index]["Menu Items"])
    
output_dataframe = pd.DataFrame(columns=Keyword_data.columns)
#print(output_dataframe)
for i in sorted_items_based_on_liking:
    #print(type(i[0]))    
    #pd.concat(output_dataframe,Keyword_data[Keyword_data["Index"] == str(i[0])])
    output_dataframe = output_dataframe.append(Keyword_data[Keyword_data["Index"] == str(i[0])])
    #print(Keyword_data[Keyword_data["Index"] == str(i[0])])
output_dataframe
# Out:
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:8: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:10: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# enter the item name: REGULAR FRIES
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Hemanth\AppData\Local\Temp\ipykernel_14144\576819517.py:140: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# ...
# 190                                HOT CHOCOLATE SMALL
# 213                                   ICED MOCHA LARGE
# 165                                 NONFAT LATTE LARGE
# 212                                  ICED MOCHA MEDIUM
# 164                                NONFAT LATTE MEDIUM
# 211                                   ICED MOCHA SMALL
# 163                                 NONFAT LATTE SMALL
# 153                                CARAMEL LATTE LARGE
# 152                               CARAMEL LATTE MEDIUM
# 186                                CARAMEL MOCHA LARGE
# 185                               CARAMEL MOCHA MEDIUM
# 151                                CARAMEL LATTE SMALL
# 184                                CARAMEL MOCHA SMALL
# 139                                     ICED TEA LARGE
# 138                                    ICED TEA MEDIUM
# 137                                     ICED TEA SMALL
# 156                               HAZELNUT LATTE LARGE
# 155                              HAZELNUT LATTE MEDIUM
# 225                                 FRAPPÃ MOCHA LARGE
# 224                                FRAPPÃ MOCHA MEDIUM
# 154                               HAZELNUT LATTE SMALL
# 223                                 FRAPPÃ MOCHA SMALL
# 228                               FRAPPÃ CARAMEL LARGE
# 129                                       SPRITE CHILD
# 227                              FRAPPÃ CARAMEL MEDIUM
# 226                               FRAPPÃ CARAMEL SMALL
# 143                                    SWEET TEA LARGE
# 142                                   SWEET TEA MEDIUM
# 37                                     SAUSAGE BURRITO
# 5                                   STEAK EGG MCMUFFIN
# 141                                    SWEET TEA SMALL
# 24                              BACON EGG CHEESE BAGEL
# 219                           ICED CARAMEL MOCHA LARGE
# 168                         NONFAT CARAMEL LATTE LARGE
# 218                          ICED CARAMEL MOCHA MEDIUM
# 167                        NONFAT CARAMEL LATTE MEDIUM
# 3                            SAUSAGE MCMUFFIN WITH EGG
# 189                         NONFAT CARAMEL MOCHA LARGE
# 188                        NONFAT CARAMEL MOCHA MEDIUM
# 217                           ICED CARAMEL MOCHA SMALL
# 166                         NONFAT CARAMEL LATTE SMALL
# 187                         NONFAT CARAMEL MOCHA SMALL
# 159                         FRENCH VANILLA LATTE LARGE
# 158                        FRENCH VANILLA LATTE MEDIUM
# 157                         FRENCH VANILLA LATTE SMALL
# 120                                    DR PEPPER LARGE
# 119                                   DR PEPPER MEDIUM
# 118                                    DR PEPPER SMALL
# 183                       MOCHA WITH NONFAT MILK LARGE
# 201                          CARAMEL ICED COFFEE LARGE
# 182                      MOCHA WITH NONFAT MILK MEDIUM
# 140                                     ICED TEA CHILD
# 200                         CARAMEL ICED COFFEE MEDIUM
# 116                                    DIET COKE LARGE
# 181                       MOCHA WITH NONFAT MILK SMALL
# 115                                   DIET COKE MEDIUM
# 199                          CARAMEL ICED COFFEE SMALL
# 114                                    DIET COKE SMALL
# 171                        NONFAT HAZELNUT LATTE LARGE
# 170                       NONFAT HAZELNUT LATTE MEDIUM
# 249                              CHOCOLATE SHAKE LARGE
# 248                             CHOCOLATE SHAKE MEDIUM
# 243                                VANILLA SHAKE LARGE
# 169                        NONFAT HAZELNUT LATTE SMALL
# 242                               VANILLA SHAKE MEDIUM
# 247                              CHOCOLATE SHAKE SMALL
# 241                                VANILLA SHAKE SMALL
# 26                              STEAK EGG CHEESE BAGEL
# 109                                  STRAWBERRY SUNDAE
# 36                                HOTCAKES AND SAUSAGE
# 28                         BIG BREAKFAST LARGE BISCUIT
# 56                                               MCRIB
# 246                             STRAWBERRY SHAKE LARGE
# 245                            STRAWBERRY SHAKE MEDIUM
# 222                    ICED NONFAT CARAMEL MOCHA LARGE
# 244                             STRAWBERRY SHAKE SMALL
# 221                   ICED NONFAT CARAMEL MOCHA MEDIUM
# 144                                    SWEET TEA CHILD
# 204                         HAZELNUT ICED COFFEE LARGE
# 203                        HAZELNUT ICED COFFEE MEDIUM
# 220                    ICED NONFAT CARAMEL MOCHA SMALL
# 202                         HAZELNUT ICED COFFEE SMALL
# 174                  NONFAT FRENCH VANILLA LATTE LARGE
# 173                 NONFAT FRENCH VANILLA LATTE MEDIUM
# 195               HOT CHOCOLATE WITH NONFAT MILK LARGE
# 194              HOT CHOCOLATE WITH NONFAT MILK MEDIUM
# 172                  NONFAT FRENCH VANILLA LATTE SMALL
# 193               HOT CHOCOLATE WITH NONFAT MILK SMALL
# 39                                      CINNAMON MELTS
# 216                  ICED MOCHA WITH NONFAT MILK LARGE
# 215                 ICED MOCHA WITH NONFAT MILK MEDIUM
# 53                                      BACON MCDOUBLE
# 214                  ICED MOCHA WITH NONFAT MILK SMALL
# 121                                    DR PEPPER CHILD
# 4                     SAUSAGE MCMUFFIN WITH EGG WHITES
# 1                                    EGG WHITE DELIGHT
# 117                                    DIET COKE CHILD
# 207                   FRENCH VANILLA ICED COFFEE LARGE
# 206                  FRENCH VANILLA ICED COFFEE MEDIUM
# 205                   FRENCH VANILLA ICED COFFEE SMALL
# 35                     HOTCAKES WHEAT MILK EGG SOY HOT
# 231                        FRAPPÃ CHOCOLATE CHIP LARGE
# 230                       FRAPPÃ CHOCOLATE CHIP MEDIUM
# 78                           CHICKEN MCNUGGETS 4 PIECE
# 79                           CHICKEN MCNUGGETS 6 PIECE
# 229                        FRAPPÃ CHOCOLATE CHIP SMALL
# 108                            HOT CARAMEL SUNDAE MILK
# 38                                      HASH BROWN HOT
# 124                               DIET DR PEPPER LARGE
# 251                               SHAMROCK SHAKE LARGE
# 123                              DIET DR PEPPER MEDIUM
# 250                              SHAMROCK SHAKE MEDIUM
# 40                                 FRUIT MAPLE OATMEAL
# 122                               DIET DR PEPPER SMALL
# 11                       SAUSAGE BISCUIT LARGE BISCUIT
# 112                            COCA COLA CLASSIC LARGE
# 111                           COCA COLA CLASSIC MEDIUM
# 51                              BACON CLUBHOUSE BURGER
# 110                            COCA COLA CLASSIC SMALL
# 100                                         SIDE SALAD
# 67                             BACON CHEDDAR MCCHICKEN
# 54                                        DAILY DOUBLE
# 55                                    JALAPEÃ O DOUBLE
# 104                              CHOCOLATE CHIP COOKIE
# 69                             BUFFALO RANCH MCCHICKEN
# 83                                        FILET O FISH
# 0               EGG MCMUFFIN WHEAT MILK SOY BARLEY HOT
# 125                               DIET DR PEPPER CHILD
# 237                   STRAWBERRY BANANA SMOOTHIE LARGE
# 236                  STRAWBERRY BANANA SMOOTHIE MEDIUM
# 235                   STRAWBERRY BANANA SMOOTHIE SMALL
# 32           BIG BREAKFAST WITH HOTCAKES LARGE BISCUIT
# 2           SAUSAGE MCMUFFIN WHEAT MILK SOY BARLEY HOT
# 113                            COCA COLA CLASSIC CHILD
# 13              SAUSAGE BISCUIT WITH EGG LARGE BISCUIT
# 30         BIG BREAKFAST WITH EGG WHITES LARGE BISCUIT
# 68                       BACON BUFFALO RANCH MCCHICKEN
# 7               BACON EGG CHEESE BISCUIT LARGE BISCUIT
# 21        SAUSAGE MCGRIDDLES WHEAT MILK SOY BARLEY HOT
# 107                          HOT FUDGE SUNDAE MILK SOY
# 94                     RANCH SNACK WRAP CRISPY CHICKEN
# 57             PREMIUM CRISPY CHICKEN CLASSIC SANDWICH
# 240                     MANGO PINEAPPLE SMOOTHIE LARGE
# 25              BACON EGG CHEESE BAGEL WITH EGG WHITES
# 239                    MANGO PINEAPPLE SMOOTHIE MEDIUM
# 59                PREMIUM CRISPY CHICKEN CLUB SANDWICH
# 95                    RANCH SNACK WRAP GRILLED CHICKEN
# 238                     MANGO PINEAPPLE SMOOTHIE SMALL
# 63             BACON CLUBHOUSE CRISPY CHICKEN SANDWICH
# 88         PREMIUM SOUTHWEST SALAD WITH CRISPY CHICKEN
# 234               BLUEBERRY POMEGRANATE SMOOTHIE LARGE
# 58            PREMIUM GRILLED CHICKEN CLASSIC SANDWICH
# 233              BLUEBERRY POMEGRANATE SMOOTHIE MEDIUM
# 232               BLUEBERRY POMEGRANATE SMOOTHIE SMALL
# 60               PREMIUM GRILLED CHICKEN CLUB SANDWICH
# 64            BACON CLUBHOUSE GRILLED CHICKEN SANDWICH
# 89        PREMIUM SOUTHWEST SALAD WITH GRILLED CHICKEN
# 85       PREMIUM BACON RANCH SALAD WITH CRISPY CHICKEN
# 20         BACON EGG CHEESE MCGRIDDLES WITH EGG WHITES
# 105                              OATMEAL RAISIN COOKIE
# 136                                DASANI WATER BOTTLE
# 44                   QUARTER POUNDER WITH BACON CHEESE
# 256                  MCFLURRY WITH OREO COOKIES MEDIUM
# 86      PREMIUM BACON RANCH SALAD WITH GRILLED CHICKEN
# 87             PREMIUM SOUTHWEST SALAD WITHOUT CHICKEN
# 255                   MCFLURRY WITH OREO COOKIES SMALL
# 23       SAUSAGE EGG CHEESE MCGRIDDLES WITH EGG WHITES
# 80                          CHICKEN MCNUGGETS 10 PIECE
# 81                          CHICKEN MCNUGGETS 20 PIECE
# 82                          CHICKEN MCNUGGETS 40 PIECE
# 131                        FAT FREE CHOCOLATE MILK JUG
# 101                                  APPLE SLICES COLD
# 46                              QUARTER POUNDER DELUXE
# 84           PREMIUM BACON RANCH SALAD WITHOUT CHICKEN
# 130                                 1 LOW FAT MILK JUG
# 253                MCFLURRY WITH M MÂ S CANDIES MEDIUM
# 252                 MCFLURRY WITH M MÂ S CANDIES SMALL
# 15       SAUSAGE BISCUIT WITH EGG WHITES LARGE BISCUIT
# 19   BACON EGG CHEESE MCGRIDDLES WHEAT MILK SOY BAR...
# 65              SOUTHERN STYLE CRISPY CHICKEN SANDWICH
# 92             HONEY MUSTARD SNACK WRAP CRISPY CHICKEN
# 22   SAUSAGE EGG CHEESE MCGRIDDLES WHEAT MILK SOY B...
# 135                     MINUTE MAID ORANGE JUICE LARGE
# 134                    MINUTE MAID ORANGE JUICE MEDIUM
# 133                     MINUTE MAID ORANGE JUICE SMALL
# 257                   MCFLURRY WITH OREO COOKIES SNACK
# 162   LATTE WITH SUGAR FREE FRENCH VANILLA SYRUP LARGE
# 93            HONEY MUSTARD SNACK WRAP GRILLED CHICKEN
# 161  LATTE WITH SUGAR FREE FRENCH VANILLA SYRUP MEDIUM
# 103                      BAKED APPLE PIE WHEAT SOY HOT
# 160   LATTE WITH SUGAR FREE FRENCH VANILLA SYRUP SMALL
# 61           PREMIUM CRISPY CHICKEN RANCH BLT SANDWICH
# 102                             FRUIT N YOGURT PARFAIT
# 62          PREMIUM GRILLED CHICKEN RANCH BLT SANDWICH
# 70         PREMIUM MCWRAP CHICKEN BACON CRISPY CHICKEN
# 254                 MCFLURRY WITH M MÂ S CANDIES SNACK
# 17        SOUTHERN STYLE CHICKEN BISCUIT LARGE BISCUIT
# 71        PREMIUM MCWRAP CHICKEN BACON GRILLED CHICKEN
# 66   MCCHICKEN WHEAT EGG SOY SESAME MUSTARD BARLEY HOT
# 72         PREMIUM MCWRAP CHICKEN RANCH CRISPY CHICKEN
# 48           HAMBURGER WHEAT SESAME MUSTARD BARLEY HOT
# 73        PREMIUM MCWRAP CHICKEN RANCH GRILLED CHICKEN
# 177  NONFAT LATTE WITH SUGAR FREE FRENCH VANILLA SY...
# 176  NONFAT LATTE WITH SUGAR FREE FRENCH VANILLA SY...
# 175  NONFAT LATTE WITH SUGAR FREE FRENCH VANILLA SY...
# 74     PREMIUM MCWRAP SOUTHWEST CHICKEN CRISPY CHICKEN
# 45           QUARTER POUNDER WITH BACON HABANERO RANCH
# 90              CHIPOTLE BBQ SNACK WRAP CRISPY CHICKEN
# 210  ICED COFFEE WITH SUGAR FREE FRENCH VANILLA SYR...
# 209  ICED COFFEE WITH SUGAR FREE FRENCH VANILLA SYR...
# 75    PREMIUM MCWRAP SOUTHWEST CHICKEN GRILLED CHICKEN
# 208  ICED COFFEE WITH SUGAR FREE FRENCH VANILLA SYR...
# 91             CHIPOTLE BBQ SNACK WRAP GRILLED CHICKEN
# 106                                KIDS ICE CREAM CONE
# 34   BIG BREAKFAST WITH HOTCAKES AND EGG WHITES LAR...
# 9    BACON EGG CHEESE BISCUIT WITH EGG WHITES LARGE...
# 49   CHEESEBURGER WHEAT MILK SOY SESAME MUSTARD BAR...
# 52   MCDOUBLE WHEAT MILK SOY SESAME MUSTARD BARLEY HOT
# 41             FRUIT MAPLE OATMEAL WITHOUT BROWN SUGAR
# 76   PREMIUM MCWRAP CHICKEN SWEET CHILI CRISPY CHICKEN
# 77   PREMIUM MCWRAP CHICKEN SWEET CHILI GRILLED CHI...
# 50   DOUBLE CHEESEBURGER WHEAT MILK SOY SESAME MUST...
# 42   BIG MAC WHEAT MILK EGG SOY SESAME MUSTARD BARL...
# 132                    MINUTE MAID 100 APPLE JUICE BOX
# 258    MCFLURRY WITH REESE S PEANUT BUTTER CUPS MEDIUM
# 43   QUARTER POUNDER WITH CHEESE WHEAT MILK SOY SES...
# 259     MCFLURRY WITH REESE S PEANUT BUTTER CUPS SNACK
# 47   DOUBLE QUARTER POUNDER WITH CHEESE WHEAT MILK ...
# 412             LOADED CHILI WHEAT GLUTEN MILK SOY HOT
# 413                  CHICKEN CILANTRO LIME LOADED BOWL
# 414                       CHICKEN HABANERO LOADED BOWL
# 415                   VEGGIE CILANTRO LIME LOADED BOWL
# 416                        VEGGIE HABANERO LOADED BOWL
# 417                          CRISPY CHICKEN CRAVEABLES
# 418                              ROAST BEEF CRAVEABLES
# 420  CREAMY MAPLE PECAN DREAM DONUT WHEAT GLUTEN MI...
# 421  PUMPKIN SPICE DREAM DONUT WHEAT GLUTEN MILK EG...
# 422  APPLE FRITTER DONUT WHEAT GLUTEN MILK EGG SOY ...
# 423  HONEY CRULLER DONUT WHEAT GLUTEN MILK EGG SOY ...
# 424  HONEY DIP DONUT WHEAT GLUTEN MILK EGG SOY TREE...
# 425  CHOCOLATE GLAZED DONUT WHEAT GLUTEN MILK EGG S...
# 426  OLD FASHIONED PLAIN DONUT WHEAT GLUTEN MILK EG...
# 427  MAPLE DIP DONUT WHEAT GLUTEN MILK EGG SOY TREE...
# 428  PUMPKIN SPICE MUFFIN WHEAT GLUTEN MILK EGG SOY...
# 429  CHOCOLATE CHIP MUFFIN WHEAT GLUTEN MILK EGG SO...
# 430  WILD BLUEBERRY MUFFIN WHEAT GLUTEN MILK EGG SO...
# 431  CHOCOLATE CROISSANT WHEAT GLUTEN MILK EGG SOY ...
# 432                                          CROISSANT
# 433  PLAIN BAGEL WHEAT GLUTEN MILK EGG SOY TREE NUT...
# 434  EVERYTHING BAGEL WHEAT GLUTEN MILK EGG SOY TRE...
# 435                                     12 GRAIN BAGEL
# 436  FOUR CHEESE BAGEL WHEAT GLUTEN MILK EGG SESAME...
# 437  CINNAMON RAISIN BAGEL WHEAT GLUTEN MILK EGG SO...
# 438  SESAME SEED BAGEL WHEAT GLUTEN MILK EGG SOY TR...
# 439                                   BLACK FOREST HAM
# 440                                    GRILLED CHICKEN
# 441                       SWEET ONION CHICKEN TERIYAKI
# 442                                  TURKEY BREAST HOT
# 443                                      VEGGIE DELITE
# 445                                     COLD CUT COMBO
# 446        CRISPY CHICKEN INCLUDES SMOKY HONEY MUSTARD
# 448                                      ITALIAN B M T
# 449      GREEN GODDESS VEGGIE INCLUDES SMASHED AVOCADO
# 452                                  MEATBALL MARINARA
# 453                                     PIZZA SUB MELT
# 458                                       STEAK CHEESE
# 460                           TUNA INCLUDES MAYONNAISE
# 461                                              B L T
# 463                                         ROAST BEEF
# 465      SPICY CRISPY CHICKEN INCLUDES CREAMY SRIRACHA
# 466                                        SUBWAY CLUB
# 467  TUNA SALAD INCLUDES LIGHT MAYONNAISE TYPE DRES...
# 469                               VEGGIE PATTY SOY HOT
# 470                                   BLACK FOREST HAM
# 471                                  TURKEY BREAST HOT
# 472                                      VEGGIE DELITE
# 512                                          EGG BACON
# 513                                         EGG CHEESE
# 514                                            EGG HAM
# 515                                        EGG SAUSAGE
#
# [524 rows x 29 columns]
